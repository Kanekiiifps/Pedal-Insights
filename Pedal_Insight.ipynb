# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mamaggie/TutorialProjects/main/data/citi_bike_trip_data.csv')

# %%
df.head ()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           326  2013-10-01 00:01:08  2013-10-01 00:06:34               239
# 1           729  2013-10-01 00:01:21  2013-10-01 00:13:30               322
# 2           520  2013-10-01 00:01:24  2013-10-01 00:10:04               174
# 3           281  2013-10-01 00:01:25  2013-10-01 00:06:06               430
# 4           196  2013-10-01 00:01:27  2013-10-01 00:04:43               403
#
#          start station name  start station latitude  start station longitude  \
# 0  Willoughby St & Fleet St               40.691966               -73.981302
# 1   Clinton St & Tillary St               40.696192               -73.991218
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3          York St & Jay St               40.701485               -73.986569
# 4            E 2 St & 2 Ave               40.725029               -73.990697
#
#    end station id             end station name  end station latitude  \
# 0             366     Clinton Ave & Myrtle Ave             40.693261
# 1             398     Atlantic Ave & Furman St             40.691652
# 2             403               E 2 St & 2 Ave             40.725029
# 3             323  Lawrence St & Willoughby St             40.692362
# 4             401      Allen St & Rivington St             40.720196
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -73.968896   16052  Subscriber       1982       1
# 1             -73.999979   19412    Customer         \N       0
# 2             -73.990697   19645  Subscriber       1984       1
# 3             -73.986317   16992  Subscriber       1985       1
# 4             -73.989978   15690  Subscriber       1986       1

# %%
df.shape
# Out:
# (40575, 15)

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  40575.000000      40575.000000            40575.000000
# mean     822.374640        449.396155               40.735229
# std      984.000376        362.462577                0.019599
# min       60.000000         72.000000               40.680342
# 25%      408.000000        306.000000               40.721816
# 50%      638.000000        405.000000               40.737050
# 75%     1028.000000        487.000000               40.750450
# max    56629.000000       3002.000000               40.770513
#
#        start station longitude  end station id  end station latitude  \
# count             40575.000000    40575.000000          40575.000000
# mean                -73.991093      450.073370             40.734885
# std                   0.012346      369.780126              0.019600
# min                 -74.017134       72.000000             40.680342
# 25%                 -74.000264      305.000000             40.721816
# 50%                 -73.990765      404.000000             40.736529
# 75%                 -73.982050      487.000000             40.750224
# max                 -73.950048     3002.000000             40.770513
#
#        end station longitude        bikeid        gender
# count           40575.000000  40575.000000  40575.000000
# mean              -73.991212  17634.191547      1.137671
# std                 0.012483   1703.451047      0.527477
# min               -74.017134  14531.000000      0.000000
# 25%               -74.001497  16146.000000      1.000000
# 50%               -73.990931  17651.000000      1.000000
# 75%               -73.982050  19093.000000      1.000000
# max               -73.950048  20664.000000      2.000000

# %%
sns.histplot(df['tripduration'])
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tripduration', ylabel='Count'>

# %%
sns.pairplot(df)
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df[['tripduration', 'gender']])
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
num_subscriber = df['usertype'].loc[df['usertype']=='Subscriber'].count()
total =len(df)
print(round(num_subscriber/total*100, 2), '% of total riders on October 1st, 2013 is annual subscribers')
# Out:
# 92.03 % of total riders on October 1st, 2013 is annual subscribers

# %%
# Q1: how does the trip length vary based on the trip start time (time of day)

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               326  2013-10-01 00:01:08  2013-10-01 00:06:34
# 1               729  2013-10-01 00:01:21  2013-10-01 00:13:30
# 2               520  2013-10-01 00:01:24  2013-10-01 00:10:04
# 3               281  2013-10-01 00:01:25  2013-10-01 00:06:06
# 4               196  2013-10-01 00:01:27  2013-10-01 00:04:43
# ...             ...                  ...                  ...
# 40570           273  2013-10-01 23:59:41  2013-10-02 00:04:14
# 40571           563  2013-10-01 23:59:43  2013-10-02 00:09:06
# 40572           490  2013-10-01 23:59:51  2013-10-02 00:08:01
# 40573          1289  2013-10-01 23:59:53  2013-10-02 00:21:22
# 40574           793  2013-10-01 23:59:58  2013-10-02 00:13:11
#
#        start station id        start station name  start station latitude  \
# 0                   239  Willoughby St & Fleet St               40.691966
# 1                   322   Clinton St & Tillary St               40.696192
# 2                   174           E 25 St & 1 Ave               40.738177
# 3                   430          York St & Jay St               40.701485
# 4                   403            E 2 St & 2 Ave               40.725029
# ...                 ...                       ...                     ...
# 40570               537   Lexington Ave & E 24 St               40.740259
# 40571               354   Emerson Pl & Myrtle Ave               40.693631
# 40572               470           W 20 St & 8 Ave               40.743453
# 40573               322   Clinton St & Tillary St               40.696192
# 40574               243   Fulton St & Rockwell Pl               40.687979
#
#        start station longitude  end station id             end station name  \
# 0                   -73.981302             366     Clinton Ave & Myrtle Ave
# 1                   -73.991218             398     Atlantic Ave & Furman St
# 2                   -73.977387             403               E 2 St & 2 Ave
# 3                   -73.986569             323  Lawrence St & Willoughby St
# 4                   -73.990697             401      Allen St & Rivington St
# ...                        ...             ...                          ...
# 40570               -73.984092             461              E 20 St & 2 Ave
# 40571               -73.962236             437      Macon St & Nostrand Ave
# 40572               -74.000040             404              9 Ave & W 14 St
# 40573               -73.991218             311       Norfolk St & Broome St
# 40574               -73.978474             243      Fulton St & Rockwell Pl
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.693261             -73.968896   16052  Subscriber
# 1                 40.691652             -73.999979   19412    Customer
# 2                 40.725029             -73.990697   19645  Subscriber
# 3                 40.692362             -73.986317   16992  Subscriber
# 4                 40.720196             -73.989978   15690  Subscriber
# ...                     ...                    ...     ...         ...
# 40570             40.735877             -73.982050   17503  Subscriber
# 40571             40.680983             -73.950048   16048  Subscriber
# 40572             40.740583             -74.005509   20006    Customer
# 40573             40.717227             -73.988021   16577  Subscriber
# 40574             40.687979             -73.978474   19440  Subscriber
#
#       birth year  gender
# 0           1982       1
# 1             \N       0
# 2           1984       1
# 3           1985       1
# 4           1986       1
# ...          ...     ...
# 40570       1989       1
# 40571       1991       2
# 40572         \N       0
# 40573       1962       2
# 40574       1948       1
#
# [40575 rows x 15 columns]

# %%
df.starttime.apply(lambda x:x[11:13]).astype('str')
# Out:
# 0        00
# 1        00
# 2        00
# 3        00
# 4        00
#          ..
# 40570    23
# 40571    23
# 40572    23
# 40573    23
# 40574    23
# Name: starttime, Length: 40575, dtype: object

# %%
df['hour'] = df.starttime.apply(lambda x:x[11:13]).astype('str')

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               326  2013-10-01 00:01:08  2013-10-01 00:06:34
# 1               729  2013-10-01 00:01:21  2013-10-01 00:13:30
# 2               520  2013-10-01 00:01:24  2013-10-01 00:10:04
# 3               281  2013-10-01 00:01:25  2013-10-01 00:06:06
# 4               196  2013-10-01 00:01:27  2013-10-01 00:04:43
# ...             ...                  ...                  ...
# 40570           273  2013-10-01 23:59:41  2013-10-02 00:04:14
# 40571           563  2013-10-01 23:59:43  2013-10-02 00:09:06
# 40572           490  2013-10-01 23:59:51  2013-10-02 00:08:01
# 40573          1289  2013-10-01 23:59:53  2013-10-02 00:21:22
# 40574           793  2013-10-01 23:59:58  2013-10-02 00:13:11
#
#        start station id        start station name  start station latitude  \
# 0                   239  Willoughby St & Fleet St               40.691966
# 1                   322   Clinton St & Tillary St               40.696192
# 2                   174           E 25 St & 1 Ave               40.738177
# 3                   430          York St & Jay St               40.701485
# 4                   403            E 2 St & 2 Ave               40.725029
# ...                 ...                       ...                     ...
# 40570               537   Lexington Ave & E 24 St               40.740259
# 40571               354   Emerson Pl & Myrtle Ave               40.693631
# 40572               470           W 20 St & 8 Ave               40.743453
# 40573               322   Clinton St & Tillary St               40.696192
# 40574               243   Fulton St & Rockwell Pl               40.687979
#
#        start station longitude  end station id             end station name  \
# 0                   -73.981302             366     Clinton Ave & Myrtle Ave
# 1                   -73.991218             398     Atlantic Ave & Furman St
# 2                   -73.977387             403               E 2 St & 2 Ave
# 3                   -73.986569             323  Lawrence St & Willoughby St
# 4                   -73.990697             401      Allen St & Rivington St
# ...                        ...             ...                          ...
# 40570               -73.984092             461              E 20 St & 2 Ave
# 40571               -73.962236             437      Macon St & Nostrand Ave
# 40572               -74.000040             404              9 Ave & W 14 St
# 40573               -73.991218             311       Norfolk St & Broome St
# 40574               -73.978474             243      Fulton St & Rockwell Pl
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.693261             -73.968896   16052  Subscriber
# 1                 40.691652             -73.999979   19412    Customer
# 2                 40.725029             -73.990697   19645  Subscriber
# 3                 40.692362             -73.986317   16992  Subscriber
# 4                 40.720196             -73.989978   15690  Subscriber
# ...                     ...                    ...     ...         ...
# 40570             40.735877             -73.982050   17503  Subscriber
# 40571             40.680983             -73.950048   16048  Subscriber
# 40572             40.740583             -74.005509   20006    Customer
# 40573             40.717227             -73.988021   16577  Subscriber
# 40574             40.687979             -73.978474   19440  Subscriber
#
#       birth year  gender hour
# 0           1982       1   00
# 1             \N       0   00
# 2           1984       1   00
# 3           1985       1   00
# 4           1986       1   00
# ...          ...     ...  ...
# 40570       1989       1   23
# 40571       1991       2   23
# 40572         \N       0   23
# 40573       1962       2   23
# 40574       1948       1   23
#
# [40575 rows x 16 columns]

# %%
# Visualize correlation
sns.scatterplot(x = 'hour', y = 'tripduration', data =df)
# Out:
# <Axes: xlabel='hour', ylabel='tripduration'>

# %%
sns.scatterplot(x = 'hour', y = 'tripduration', data = df, hue = 'usertype')
# Out:
# <Axes: xlabel='hour', ylabel='tripduration'>

# %%
# Q2: Which bike stations are the most popular? Where do most of the trip start from?

# %%
df2 = df.groupby(['start station id']).size().reset_index(name = 'counts')

# %%
df2
# Out:
#      start station id  counts
# 0                  72     112
# 1                  79      91
# 2                  82      39
# 3                  83      52
# 4                 116     213
# ..                ...     ...
# 323              2017     127
# 324              2021     228
# 325              2022     105
# 326              2023      74
# 327              3002     186
#
# [328 rows x 2 columns]

# %%
temp = df.drop_duplicates('start station id')
#left join
df2 = pd.merge(df2, temp[['start station id', 'start station name', 'start station latitude',
                    'start station longitude']], how = 'left', on = ['start station id'])

# %%
# %pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: folium in /home/bfb12e4a-aff6-4a6c-9e51-851eea445df2/.local/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /home/bfb12e4a-aff6-4a6c-9e51-851eea445df2/.local/lib/python3.10/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# initialize a map, need visuals
m = folium.Map(location = [40.691966, -73.981302], tiles = 'OpenStreetMap', zoom_start = 12)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1177d91c1c3f2840a5aceb28bd4e0ed7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1177d91c1c3f2840a5aceb28bd4e0ed7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1177d91c1c3f2840a5aceb28bd4e0ed7 = L.map(
#                 &quot;map_1177d91c1c3f2840a5aceb28bd4e0ed7&quot;,
#                 {
#                     center: [40.691966, -73.981302],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88b43bed124a48c7eec10353972841db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88b43bed124a48c7eec10353972841db.addTo(map_1177d91c1c3f2840a5aceb28bd4e0ed7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0, len(df2)):
    folium.Circle(
        location = [df2.iloc[i]['start station latitude'], df.iloc[i]['start station longitude']],
        popup = df2.iloc[i]['start station name'],
        radius = float(df2.iloc[i]['counts'])/2,
        color = 'green',
        fill = True, fill_color = 'green' 
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1177d91c1c3f2840a5aceb28bd4e0ed7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1177d91c1c3f2840a5aceb28bd4e0ed7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1177d91c1c3f2840a5aceb28bd4e0ed7 = L.map(
#                 &quot;map_1177d91c1c3f2840a5aceb28bd4e0ed7&quot;,
#                 {
#                     center: [40.691966, -73.981302],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88b43bed124a48c7eec10353972841db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88b43bed124a48c7eec10353972841db.addTo(map_1177d91c1c3f2840a5aceb28bd4e0ed7);
#
#
#             tile_layer_88b43bed124a48c7eec10353972841db.addTo(map_1177d91c1c3f2840a5aceb28bd4e0ed7);
#
#
#             var circle_c026ad036744890e3d2278d1722abde6 = L.circle(
#                 [40.76727216, -73.9813018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 56.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1177d91c1c3f2840a5aceb28bd4e0ed7);
#
#
#         var popup_0e84fe83ed68506448ca3b8221c18721 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3ca3ccb07afc3d61a54be5966ad9ee7 = $(`&lt;div id=&quot;html_f3ca3ccb07afc3d61a54be5966ad9ee7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W 52 St &amp; 11 Ave&lt;/div&gt;`)[0];
#                 popup_0e84fe83ed68506448ca3b8221c18721.setContent(html_f3ca3ccb07afc3d61a54be5966ad9ee7);
#
#
#
#         circle_c026ad036744890e3d2278d1722abde6.bindPopup(popup_0e84fe83ed68506448ca3b8221c18721)
#         ;
#
#
#
#
#             var circle_80a59f8307edd2cc379f878dc6e180ad = L.circle(
#                 [40.71911552, -73.991218],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 45.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1177d91c1c3f2840a5aceb28bd4e0ed7);
#
#
#         var popup_91f4ebff69b4bc36b77b49edf96d668e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be800c76b388eadf513bcb8c3a880346 = $(`&lt;div id=&quot;html_be800c76b388eadf513bcb8c3a880346&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Franklin St &amp; W Broadway&lt;/div&gt;`)[0];
#                 popup_91f4ebff69b4bc36b77b49edf96d668e.setContent(html_be800c76b388eadf513bcb8c3a880346);
#
#
#
#         circle_80a59f8307edd2cc379f878dc6e180ad.bindPopup(popup_91f4ebff69b4bc36b77b49edf96d668e)
#         ;
#
#
#
#
#             var circle_f272bc07434b2aebd4c42f3db725420a = L.circle(
#                 [40.71117416, -73.97738662],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1177d91c1c3f2840a5aceb28bd4e0ed7);
#
#
#         var popup_7866dc1af777cb955fd47266ec157557 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_517ea13b46fcab2165eff5b44841934b = $(`&lt;div id=&quot;html_517ea13b46fcab2165eff5b44841934b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St James Pl &amp; Pearl St&lt;/div&gt;`)[0];
#                 popup_7866dc1af777cb955fd47266ec157557.setContent(html_517ea13b46fcab2165eff5b44841934b);
#
#
#
#         circle_f272bc07434b2aebd4c42f3db725420a.bindPopup(popup_7866dc1af777cb955fd4726
